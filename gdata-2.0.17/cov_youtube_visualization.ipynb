# %%
import gdata.youtube.service
import pandas


data = !cat cov_youtube_stats | grep 'href="/watch?v='
my_list=[]
my_dict={}


for line in data:
    first = line.split()[1]
    second = first.split('=')[-1]
    third = second.split('"')[0]
    my_list.append(third)
    
for item in set(my_list):
    target_video = item
    yt_service = gdata.youtube.service.YouTubeService()
    yt_service.ssl = True
    yt_service.developer_key = 'AI39si6rrh_W0KC3Pl9RPEij-S11vBt-GRFBCBRN25kZ_DHCTNlZnHhWAn4_CUT3JA1RYyHhWB31IXBwzkqYgBd0tYahhYqs1g'
    yt_service.client_id = 'botviewers'

    entry = yt_service.GetYouTubeVideoEntry(video_id=target_video)
    print 'Video title: %s' % entry.media.title.text
    print 'View Count: %s' % entry.statistics.view_count
    print
    
    my_dict[entry.media.title.text] = int(entry.statistics.view_count)
# Out:
# Video title: Transportation 2040  - A transportation vision for the City of Vancouver
# View Count: 105
#
# Video title: Closing Remarks - Healthy City Summit
# View Count: 1
#
# Video title: Increase Employment for Aboriginal People - Healthy City Summit
# View Count: 9
#
# Video title: Patricia Daly - Healthy City Summit
# View Count: 10
#
# Video title: Full Panel Discussion - Healthy City Summit
# View Count: 39
#
# Video title: Walking the Talk - Healthy City Summit
# View Count: 2
#
# Video title: There's No Place Like Home: Highlights Reel
# View Count: 81
#
# Video title: Mayor Gregor Robertson Opening Remarks - Healthy City Summit
# View Count: 18
#
# Video title: Andrew Petter - Healthy City Summit
# View Count: 5
#
# Video title: Salmon return to Still Creek
# View Count: 77
#
# Video title: There's No Place Like Home: Dennis Wilkinson and Barbara Shaw West End Story
# View Count: 65
#
# Video title: Raincity Housing - Healthy City Summit
# View Count: 10
#
# Video title: Panel Discussion Moderated by Andre - Healthy City Summit
# View Count: 28
#
# Video title: There's No Place Like Home: Spencer Chandra-Herbert West End Story
# View Count: 43
#
# Video title: Lynda Gray - Healthy City Summit
# View Count: 4
#
# Video title: CitizenU - Healthy City Summit
# View Count: 2
#
# Video title: West End Community Plan - City of Vancouver
# View Count: 496
#
# Video title: Building Physical Literacy - Healthy City Summit
# View Count: 5
#
# Video title: Compulsive Hoarding - Healthy City Summit
# View Count: 3
#
# Video title: Improving Methadone Maintanance - Healthy City Summit
# View Count: 2
#
# Video title: re:THINK REVEAL Summary Video
# View Count: 256
#
# Video title: City of Vancouver residential Food Scraps Recycling Program
# View Count: 903
#
# Video title: Bill Quinn - First Nations Elder Shares His Story
# View Count: 131
#
# Video title: Andre Picard Keynote Full - Healthy City Summit
# View Count: 20
#
# Video title: Food Network Movment - Healthy City Summit
# View Count: 3
#
# Video title: There's No Place Like Home: Irene Santos and Sandra Goodridge's West End Story
# View Count: 33
#
# Video title: VIADUCTS Transportation Presentation (Part 2) - City of Vancouver
# View Count: 95
#
# Video title: SACY - Healthy City Summit
# View Count: 1
#
# Video title: Trevor Hancock - Healthy City Summit
# View Count: 15
#
# Video title: Romi Chandra Herbert - Healthy City Summit
# View Count: 10

# %%
my_dict
# Out:
# {'Andre Picard Keynote Full - Healthy City Summit': 20,
#  'Andrew Petter - Healthy City Summit': 5,
#  'Bill Quinn - First Nations Elder Shares His Story': 131,
#  'Building Physical Literacy - Healthy City Summit': 5,
#  'CitizenU - Healthy City Summit': 2,
#  'City of Vancouver residential Food Scraps Recycling Program': 903,
#  'Closing Remarks - Healthy City Summit': 1,
#  'Compulsive Hoarding - Healthy City Summit': 3,
#  'Food Network Movment - Healthy City Summit': 3,
#  'Full Panel Discussion - Healthy City Summit': 39,
#  'Improving Methadone Maintanance - Healthy City Summit': 2,
#  'Increase Employment for Aboriginal People - Healthy City Summit': 9,
#  'Lynda Gray - Healthy City Summit': 4,
#  'Mayor Gregor Robertson Opening Remarks - Healthy City Summit': 18,
#  'Panel Discussion Moderated by Andre - Healthy City Summit': 28,
#  'Patricia Daly - Healthy City Summit': 10,
#  'Raincity Housing - Healthy City Summit': 10,
#  'Romi Chandra Herbert - Healthy City Summit': 10,
#  'SACY - Healthy City Summit': 1,
#  'Salmon return to Still Creek': 77,
#  "There's No Place Like Home: Dennis Wilkinson and Barbara Shaw West End Story": 65,
#  "There's No Place Like Home: Highlights Reel": 81,
#  "There's No Place Like Home: Irene Santos and Sandra Goodridge's West End Story": 33,
#  "There's No Place Like Home: Spencer Chandra-Herbert West End Story": 43,
#  'Transportation 2040  - A transportation vision for the City of Vancouver': 105,
#  'Trevor Hancock - Healthy City Summit': 15,
#  'VIADUCTS Transportation Presentation (Part 2) - City of Vancouver': 95,
#  'Walking the Talk - Healthy City Summit': 2,
#  'West End Community Plan - City of Vancouver': 496,
#  're:THINK REVEAL Summary Video': 256}

# %%
sorted_dict = sorted(my_dict.items(), key=lambda x: x[1], reverse=True)
sorted_dict
# Out:
# [('City of Vancouver residential Food Scraps Recycling Program', 903),
#  ('West End Community Plan - City of Vancouver', 496),
#  ('re:THINK REVEAL Summary Video', 256),
#  ('Bill Quinn - First Nations Elder Shares His Story', 131),
#  ('Transportation 2040  - A transportation vision for the City of Vancouver',
#   105),
#  ('VIADUCTS Transportation Presentation (Part 2) - City of Vancouver', 95),
#  ("There's No Place Like Home: Highlights Reel", 81),
#  ('Salmon return to Still Creek', 77),
#  ("There's No Place Like Home: Dennis Wilkinson and Barbara Shaw West End Story",
#   65),
#  ("There's No Place Like Home: Spencer Chandra-Herbert West End Story", 43),
#  ('Full Panel Discussion - Healthy City Summit', 39),
#  ("There's No Place Like Home: Irene Santos and Sandra Goodridge's West End Story",
#   33),
#  ('Panel Discussion Moderated by Andre - Healthy City Summit', 28),
#  ('Andre Picard Keynote Full - Healthy City Summit', 20),
#  ('Mayor Gregor Robertson Opening Remarks - Healthy City Summit', 18),
#  ('Trevor Hancock - Healthy City Summit', 15),
#  ('Romi Chandra Herbert - Healthy City Summit', 10),
#  ('Raincity Housing - Healthy City Summit', 10),
#  ('Patricia Daly - Healthy City Summit', 10),
#  ('Increase Employment for Aboriginal People - Healthy City Summit', 9),
#  ('Building Physical Literacy - Healthy City Summit', 5),
#  ('Andrew Petter - Healthy City Summit', 5),
#  ('Lynda Gray - Healthy City Summit', 4),
#  ('Compulsive Hoarding - Healthy City Summit', 3),
#  ('Food Network Movment - Healthy City Summit', 3),
#  ('CitizenU - Healthy City Summit', 2),
#  ('Improving Methadone Maintanance - Healthy City Summit', 2),
#  ('Walking the Talk - Healthy City Summit', 2),
#  ('Closing Remarks - Healthy City Summit', 1),
#  ('SACY - Healthy City Summit', 1)]

# %%
ts = pandas.Series(dict(sorted_dict))
ts.plot(kind='barh')
